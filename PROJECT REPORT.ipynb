# %% [markdown]
#   # *PROJECT REPORT*

# %% [markdown]
#    # *COURSERA IBM DATA SCIENCE CAPSTONE PROJECT : FINDING IDEAL LOCATION FOR SETTING UP A NEW GYM IN TORONTO*

# %% [markdown]
# ### Report prepared by Saurabh.S

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### For this analysis project, its a scenario where the owner of a famous GYM circuit in the U.S.A is trying to set up their gyms in parts of Toronto, Canada. He wants us to take everything into consideration such as population of the regions, the locality, weather its a prime or a quiet locality and also the competition after he sets up his gyms.He wants us to provide a brief report in which he wants us to show him the competition that already exists and he wants us to suggest different localities and neighborhoods and places which would be ideal for him to set up.He also wants us to give him the best 3 neighborhoods where people work on fitness a lot and it is an active population and there is scope of people switching to his gym.

# %% [markdown]
# ## BUSINESS PROBLEM

# %% [markdown]
# ### The objective of this capstone project is to find the most ideal location for the owner to set up his gym franchises in Toronto, Canada.By using data analysis methodoligies and machine learning models such as clustering by K-means, this project aims to provide a solution and visualize ideal spots for the gym to be ideally located. The business question is, if an entrepeneur wants to expand his gymnasium,where should they consider opening it?

# %% [markdown]
# ## Target Audience

# %% [markdown]
# ### A gym owner wants us to find ideal locations for his business

# %% [markdown]
# ## DATA

# %% [markdown]
# #### To start with, we will need the list of neighborhoods in toronto canada. We would need a common attribute to group them by and that would be the postal code.Then we would need the latitudes and longitudes of those neighborhoods and then we have to group them together and merge the postalcode and location coordinates datasets. Then we would need overall venue data about the neighbourhoods and finally we would need the gym venues data in those neighborhoods to find an ideal location.

# %% [markdown]
# ## THE EXTRACTION AND MANIPULATION OF DATA

# %% [markdown]
# #### We can scrap the neighborhoods data from wikipedia for Toronto in Ontario, Canada. After this we have to clean the data and do the necessary ammendments to the data. Then we can get the lattiude and longitude data from the net as a csv file for the neighborhoods in Toronto.Then we have to clean and sort the data furthermore and merge few datasets to make a single final sorted dataframe. Then we use the FourSquare API to find out the venue data of the neighborhoods and find out the different venues in the neighborhoods and sort out the venues according to our need and then create a separate dataset for gyms.Then we clean that dataset furthermore and proceed to clustering. After the clustering we Map those clusters and visualize our data in a way which is easily apprehendable.

# %% [markdown]
# ## METHODOLOGY

# %% [markdown]
# ### First i need to get the list of neighborhoods in Toronto, Canada. This can be done by extracting the list from the wikipedia page under Postal Codes for Canada in M:. This webscraping can be done by using the pandas html table scraping method. This pulls the data directly into a data frame saving time and code. This dataframe consisted of postal codes of the neighborhoods. Then to get the location co-ordinates of these neighborhoods i used the csv file which was provided by the IBM team. After gathering the co- ordinates the dataframe of the postal codes and the location dataframe were merged and then by using the folium package a visualization map was created mapping these coordinates. Then by using the FourSquare API we get the top 100 venues around the neighborhoods in a 500 m radius.From foursquare it is easier as i was able to extract the name, category and the type of the venue and to my surprise even the lattitude and longitude of the venue and which resulted in a clean dataset of venues.Then some cleaning is done on this dataset to prepare it for k clustering later.Scanning the dataset for the keyword venue as "gym" brings us all the venues and locations of the gyms in those neighborhoods.Then this makes a separate data frame of all the gymnasiums present around the neighborhood. Finally a clustering algorithm is performed on this final cleaned dataset which identifies k points and allocates everydata point to its nearest cluster. Three clusters were made according to the frequency of the gym venues and then by folium packge this was mapped and it clearly showed and visualized the different clusters and the mark points which differentiated 2 clusters and the locations of the gyms which would be considered as competition.

# %% [markdown]
# ## RESULTS

# %% [markdown]
# ## THE MAPPING AFTER CLUSTERING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## RECOMMENDATIONS

# %% [markdown]
# ### As we can see from the mapping that central toronto is widely populated with gymnasiums, infact some of them are even next to each other implying there is heavy competition.If we look at the coastal regions around toronto we can see that the red clusters dominate but on the east york side of Toronto there are not many gyms in the vicinity. We can see the train line goes through East York and that means that many potential customers could enroll as they take the train either on their way to work or from their way back. East york would be one locality to look at and it could be considered as a good option to start.

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# ## In this analysis project we have identified the business problem which was given, we have specified the data required, we have acquired it,extracted it and manipulated it to fit our purpose. We have merged more than one dataframes into one and performed ideal algorithms on it to provide the best possible recommendation to the stake holder.
